# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
from sklearn.metrics import r2_score

# %%
for i in os.listdir("../chauvenetv2.0/docs/"):
    PATH = "../chauvenetv2.0/docs/" + i
    file1 = open(PATH, 'r')
    line  = file1.readlines()

print(line)
# Out:
# ['Iteration : 0  Outlier : 0  Forward : 0  Backward : 0\n', 'Mean : 4.89 Std : 0.22 N : 100\n', 'Iteration : 1  Outlier : 15  Forward : 6  Backward : 91\n', 'Mean : 4.83 Std : 0.19 N : 85\n', 'Iteration : 2  Outlier : 12  Forward : 6  Backward : 79\n', 'Mean : 4.79 Std : 0.16 N : 73\n', 'Iteration : 3  Outlier : 12  Forward : 6  Backward : 67\n', 'Mean : 4.74 Std : 0.14 N : 61\n', 'Iteration : 4  Outlier : 10  Forward : 5  Backward : 56\n', 'Mean : 4.71 Std : 0.12 N : 51\n', 'Iteration : 5  Outlier : 10  Forward : 5  Backward : 46\n', 'Mean : 4.67 Std : 0.10 N : 41\n', 'Iteration : 6  Outlier : 10  Forward : 5  Backward : 36\n', 'Mean : 4.63 Std : 0.07 N : 31\n', 'Iteration : 7  Outlier : 4  Forward : 2  Backward : 29\n', 'Mean : 4.61 Std : 0.06 N : 27\n', 'Iteration : 8  Outlier : 4  Forward : 2  Backward : 25\n', 'Mean : 4.59 Std : 0.06 N : 23\n', 'Iteration : 9  Outlier : 4  Forward : 2  Backward : 21\n', 'Mean : 4.58 Std : 0.05 N : 19\n', 'Iteration : 10  Outlier : 4  Forward : 2
# ...

# %%
plt
plt.show()

# %%
fig, [ax, ax1] = plt.subplots(1, 2)
fig.set_size_inches(10, 5)
ax.scatter(N, mean, facecolors='none', edgecolors='k', label="mean")
ax1.scatter(N, std, facecolors='none', edgecolors='k', label="std")

ax1.set_xlabel("Sample Size")
ax.set_xlabel("Sample Size")

ax.set_ylabel("Mean")
ax1.set_ylabel("Standard Deviation")

ax.set_title("Mean over iteration")
ax1.set_title("Standard Deviation over iteration")
ax.invert_xaxis()
ax1.invert_xaxis()
plt.show()
