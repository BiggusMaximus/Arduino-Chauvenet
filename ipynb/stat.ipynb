# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
mean1 = [4.90, 4.84, 4.79, 4.75, 4.72, 4.69, 4.66, 4.64, 4.61, 4.59, 4.57, 4.56, 4.52, 4.51, 4.50]
std1 = [0.22, 0.18, 0.15, 0.13, 0.11, 0.09, 0.08, 0.07, 0.06, 0.05, 0.04, 0.04, 0.02, 0.01, 0.00]
N1 = [100, 84, 72, 61, 52, 44, 36, 28, 22, 16, 12,8 ,4,3,2]

mean2 = [4.94, 4.88, 4.82, 4.78, 4.74, 4.72, 4.70, 4.67, 4.65, 4.63, 4.61, 4.60, 4.58]
std2 = [0.23, 0.19, 0.15, 0.12, 0.10, 0.09, 0.08, 0.06, 0.05, 0.04, 0.03, 0.02, 0.01]
N2 = [100, 85, 71, 61, 51, 45, 38, 31, 25, 19, 13, 7, 5]

mean3 = [4.88, 4.80, 4.72, 4.66, 4.63, 4.59, 4.57, 4.57, 4.54, 4.53, 4.52]
std3 = [0.22, 0.17, 0.13, 0.1, 0.09, 0.07, 0.06, 0.06, 0.04, 0.03, 0.02]
N3 = [100, 78, 56, 40, 32, 24, 20, 19, 14, 13, 11]

mean4= [4.87, 4.80, 4.75, 4.70, 4.67, 4.64, 4.60, 4.56, 4.54, 4.54]
std4 = [0.24, 0.2, 0.17, 0.14, 0.12, 0.10, 0.07, 0.05, 0.04, 0.03]
N4 = [100, 83, 71, 59, 52, 46, 34, 22, 18, 16]

mean5 = [4.89, 4.83, 4.79, 4.74, 4.71, 4.67, 4.63, 4.61, 4.59, 4.58, 4.56, 4.55, 4.52, 4.49, 4.48]
std5 = [0.22, 0.19, 0.16, 0.14, 0.12, 0.10, 0.07, 0.06, 0.06, 0.05, 0.05, 0.05, 0.04, 0.03, 00]
N5 = [100, 85, 73, 61, 51, 41, 31, 27, 23, 19, 15, 11, 7, 3, 2]

# %%
fig, [ax, ax1] = plt.subplots(1, 2)
fig.set_size_inches(10, 5)
ax.scatter(N1, mean1, facecolors='none', edgecolors='k', label="1st")
ax.scatter(N2, mean2, facecolors='none', edgecolors='r', label="2nd")
ax.scatter(N3, mean3, facecolors='none', edgecolors='b', label="3rd")
ax.scatter(N4, mean4, facecolors='none', edgecolors='y', label="4th")
ax.scatter(N5, mean5, facecolors='none', edgecolors='g', label="5th")

ax1.scatter(N1, std1, facecolors='none', edgecolors='k', label="1st")
ax1.scatter(N2, std2, facecolors='none', edgecolors='r', label="2nd")
ax1.scatter(N3, std3, facecolors='none', edgecolors='b', label="3rd")
ax1.scatter(N4, std4, facecolors='none', edgecolors='y', label="4th")
ax1.scatter(N5, std5, facecolors='none', edgecolors='g', label="5th")

ax.plot(N1, mean1, color='k', label="1st")
ax.plot(N2, mean2, color='r', label="2nd")
ax.plot(N3, mean3, color='b', label="3rd")
ax.plot(N4, mean4, color='y', label="4th")
ax.plot(N5, mean5, color='g', label="5th")

ax1.set_xlabel("Sample Size")
ax.set_xlabel("Sample Size")

ax.set_ylabel("Mean")
ax1.set_ylabel("Standard Deviation")

ax.set_title("Mean over iteration")
ax1.set_title("Standard Deviation over iteration")
ax.invert_xaxis()
ax1.invert_xaxis()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 8), dpi=100)
plt.rcParams.update({'font.size': 22})
plt.scatter(N1, std1, facecolors='none', edgecolors='k', label="1st sample")
plt.scatter(N2, std2, facecolors='none', edgecolors='r', label="2nd sample")
plt.scatter(N3, std3, facecolors='none', edgecolors='b', label="3rd sample")
plt.scatter(N4, std4, facecolors='none', edgecolors='y', label="4th sample")
plt.scatter(N5, std5, facecolors='none', edgecolors='g', label="5th sample")

# count = 0
# for i in N1:
#     print(std1[count] - 0.005)
#     plt.axvline(x=i, ymin=(std1[count] - 0.005))
#     count += 1

plt.plot(N2, std2, color='k')
plt.plot(N1, std1, color='r')
plt.plot(N3, std3, color='b')
plt.plot(N4, std4, color='y')
plt.plot(N5, std5, color='g')
plt.gca().invert_xaxis()
plt.ylabel("Standard Deviation")
plt.xlabel("Sample Size (N)")

plt.rcParams.update({'font.size': 22})
plt.legend()
plt.show()

# %%
data_raw = [5.33, 5.33, 5.33, 5.31, 5.31, 5.31, 5.28, 5.28, 5.28, 5.26, 5.26, 5.26, 5.23, 5.23, 5.23, 5.23, 5.21, 5.21, 5.21, 5.18, 5.18, 5.18, 5.16, 5.16, 5.16, 5.14, 5.14, 5.11, 5.11, 5.11, 5.11, 5.09, 5.09, 5.09, 5.06, 5.06, 5.04, 5.04, 5.04, 5.04, 5.01, 5.01, 5.01, 4.99, 4.99, 4.99, 4.96, 4.96, 4.94, 4.94, 4.94, 4.94, 4.96, 4.96, 5.04, 5.11, 5.21, 5.33, 5.50, 5.67, 5.77, 5.75, 5.75, 5.75, 5.75, 
5.72, 5.72, 5.70, 5.70, 5.70, 5.67, 5.67, 5.67, 5.65, 5.65, 5.65, 5.62, 5.62, 5.62, 5.60, 5.60, 5.60, 5.57, 5.57, 5.55, 5.55, 5.55, 5.53, 5.53, 5.53, 5.50, 5.50, 5.50, 5.48, 5.48, 5.48, 5.45, 5.45, 5.45, 5.43]

data_chauvenet = [4.94, 4.94, 4.94, 4.96, 4.96, 4.96, 4.96, 4.99, 4.99, 4.99, 5.01, 5.01, 5.01, 5.04, 5.04, 5.04, 5.04, 5.04]

n_raw = np.linspace(0, len(data_raw), len(data_raw))
n_chauvenet = np.linspace(0, 100, len(data_chauvenet))

# %%
plt.figure(figsize=(15, 8), dpi=100)
plt.rcParams.update({'font.size': 15})
plt.scatter(n_chauvenet, data_chauvenet, facecolors='none', edgecolors='k', label="Chauvenet")
plt.scatter(n_raw, data_raw, facecolors='none', edgecolors='r', label="Raw Data")

y_raw = np.polyfit(n_raw, data_raw, 15)
y_raw = np.poly1d(y_raw)
y_chauvenet = np.polyfit(n_chauvenet, data_chauvenet, 3)
y_chauvenet = np.poly1d(y_chauvenet)
plt.plot(n_chauvenet, y_chauvenet(n_chauvenet))
plt.plot(n_raw, y_raw(n_raw))

# %%
df = pd.read_csv('../chauvenetv2.0/docs/compare.txt')
df["Arduino"].max()
# Out:
# 5.04

# %%
n = np.linspace(0, len(df["Arduino"]), len(df["Arduino"]))
plt.figure(figsize=(15, 8), dpi=100)
plt.rcParams.update({'font.size': 15})
plt.scatter(n, df["Arduino"], facecolors='none', edgecolors='k', label="Chauvenet")
plt.scatter(n, df["multimeter"], facecolors='none', edgecolors='r', label="Multimeter")

y_raw = np.polyfit(n, df["multimeter"], 99)
y_raw = np.poly1d(y_raw)
y_chauvenet = np.polyfit(n, df["Arduino"], 99)
y_chauvenet = np.poly1d(y_chauvenet)
plt.axhline(y=5, color='k', linestyle="--")
plt.plot(n, y_chauvenet(n))
plt.plot(n, y_raw(n))
plt.legend()
plt.show()
# Out:
# g:\Program\Python\__env\Yolo2TFLite\lib\site-packages\numpy\lib\polynomial.py:658: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# g:\Program\Python\__env\Yolo2TFLite\lib\site-packages\IPython\core\interactiveshell.py:3553: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# g:\Program\Python\__env\Yolo2TFLite\lib\site-packages\IPython\core\interactiveshell.py:3553: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
n = np.linspace(0, len(df["Arduino"]), len(df["Arduino"]))
plt.figure(figsize=(15, 8), dpi=100)
plt.rcParams.update({'font.size': 22})
plt.scatter(n, df["multimeter"], facecolors='none', edgecolors='r', label="Instrument 1")
plt.scatter(n, df["Arduino"], facecolors='none', edgecolors='k', label="Instrument 2 with Chauvenet")

plt.axhline(y=5, color='k', linestyle="--")
plt.plot(n, df["Arduino"])
plt.plot(n, df["multimeter"])
plt.ylabel("Voltage")
plt.xlabel("Number of data")
plt.ylim([4.8, 5.2])
plt.legend()
plt.show()

# %%
df_read = pd.read_csv("../chauvenetv2.0/docs/multimeter_sensor.txt")
df_read
# Out:
#     arduino  multimeter  chauvenet
# 0      5.00        5.01        5.0
# 1      5.00        5.01        5.0
# 2      5.01        5.01        5.0
# 3      5.00        5.01        5.0
# 4      5.00        5.01        5.0
# ..      ...         ...        ...
# 70     5.01        5.01        NaN
# 71     5.00        5.01        NaN
# 72     5.01        5.01        NaN
# 73     5.00        5.01        NaN
# 74     5.01        5.01        NaN
#
# [75 rows x 3 columns]

# %%
n = np.linspace(0, len(df_read["arduino"][:25]), len(df_read["arduino"][:25]))
plt.figure(figsize=(15, 8), dpi=100)
plt.rcParams.update({'font.size': 22})
plt.scatter(n, df_read["multimeter"][:25], facecolors='none', edgecolors='r', label="Instrument 1")
plt.scatter(n, df_read["arduino"][:25], facecolors='none', edgecolors='k', label="Instrument 2 without Chauvenet")
plt.scatter(n, df_read["chauvenet"][:25], facecolors='none', edgecolors='b', label="Instrument 2 with Chauvenet")

plt.axhline(y=5, color='k', linestyle="--")
plt.plot(n, df_read["arduino"][:25], color='k')
plt.plot(n, df_read["multimeter"][:25],color='r')
plt.plot(n, df_read["chauvenet"][:25],color='b')
plt.ylim([4.85, 5.15])
plt.ylabel("Voltage")
plt.xlabel("Number of data")
plt.legend()
plt.show()

# %%
error_multimeter = ((5 - df_read.multimeter)/5).mean()
error_multimeter * 100
# Out:
# -0.19999999999999568
